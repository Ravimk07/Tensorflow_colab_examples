# %% [markdown]
# ## Intro to deep learning for medical imaging by [MD.ai](https://www.md.ai)
#
# ## Lesson 2. Lung X-Rays Semantic Segmentation
#
# This lesson uses a MD.ai implemenation of [U-Net for Semantic Segmentation](https://arxiv.org/abs/1505.04597) of Lung X-Rays.
#
# The MD.ai annotator is used to view the DICOM images, and to create the image level annotation. The MD.ai python client library is then used to download images and annotations, prepare the datasets, then are then used to train the model for classification.
#
# - MD.ai annotator project URL: https://public.md.ai/annotator/project/aGq4k6NW/workspace
# - MD.ai python client libray URL: https://github.com/mdai/mdai-client-py
# - MD.ai documentation URL: https://docs.md.ai/
#
# The original public dataset is found [here](https://ceb.nlm.nih.gov/repositories/tuberculosis-chest-x-ray-image-data-sets/). This tutorial and use of this public dataset is for education purpose only. Note that any publications resulting from the use of this data must attribute the data to National Library of Medicine, National Institutes of Health, Bethesda, MD, USA, and cite this article: https://lhncbc.nlm.nih.gov/publication/pub9356
# For further information regarding the dataset, see [this faq](https://openi.nlm.nih.gov/faq.php).
#
# **Intro to deep learning for medical imaging lessons**
#
# - Lesson 1. Classification of chest vs. adominal X-rays using TensorFlow/Keras [Github](https://github.com/mdai/ml-lessons/blob/master/lesson1-xray-images-classification.ipynb) [Annotator](https://public.md.ai/annotator/project/PVq9raBJ)
#
# - Lesson 2. Lung X-Rays Semantic Segmentation using UNets. [Github](https://github.com/mdai/ml-lessons/blob/master/lesson2-lung-xrays-segmentation.ipynb)
# [Annotator](https://public.md.ai/annotator/project/aGq4k6NW/workspace)
#
# - Lesson 3. RSNA Pneumonia detection using Kaggle data format [Github](https://github.com/mdai/ml-lessons/blob/master/lesson3-rsna-pneumonia-detection-kaggle.ipynb) [Annotator](https://public.md.ai/annotator/project/LxR6zdR2/workspace)
#
# - Lesson 3. RSNA Pneumonia detection using MD.ai python client library [Github](https://github.com/mdai/ml-lessons/blob/master/lesson3-rsna-pneumonia-detection-mdai-client-lib.ipynb) [Annotator](https://public.md.ai/annotator/project/LxR6zdR2/workspace)
#
# *Copyright 2018 MD.ai, Inc.
# Licensed under the Apache License, Version 2.0*

# %% [markdown]
# **Clink [here](https://colab.research.google.com/github/mdai/ml-lessons/blob/master/lesson2-lung-xrays-segmentation.ipynb) to launch this notebook on Google Colab.**
# For GPU, go to Runtime -> Change runtime type -> switch to Python 3, and turn on GPU.

# %%
# install dependencies not included by Colab
# use pip3 to ensure compatibility w/ Google Deep Learning Images 
# !pip3 install -q pydicom 
# !pip3 install -q tqdm 
# !pip3 install -q imgaug

# %% [markdown]
# ### Import the `mdai` library
#
# On Colab, run the block below to install the `mdai` client library into your python environment.

# %%
# !pip3 install --upgrade -q mdai

# %%
import os
import sys
import random
import math
import numpy as np
import cv2
import matplotlib.pyplot as plt
import json
import pydicom
from imgaug import augmenters as iaa

import skimage.io
import skimage.measure
from tqdm import tqdm
from PIL import Image

import requests
import shutil
import zipfile

# %%
import mdai
mdai.__version__
# Out:
# '0.0.5'

# %% [markdown]
# ### Create an `mdai` client
#
# The mdai client requires an access token, which authenticates you as the user. To create a new token or select an existing token, navigate to the "Personal Access Tokens" tab on your user settings page at the specified MD.ai domain (e.g., public.md.ai).
#
# **Important: keep your access tokens safe. Do not ever share your tokens.**

# %%
mdai_client = mdai.Client(domain='public.md.ai', access_token="0d602f9fdf6a2835b472255d8a82836f ")
# Out:
# Successfully authenticated to public.md.ai.

# %% [markdown]
# ### Define project
#
# Define a project you have access to by passing in the project id. The project id can be found in the URL in the following format: `https://public.md.ai/annotator/project/{project_id}`.
#
# For example, `project_id` would be `XXXX` for `https://public.md.ai/annotator/project/XXXX`.
#
# Specify optional `path` as the data directory (if left blank, will default to current working directory).

# %%
p = mdai_client.project('aGq4k6NW', path='./lesson2-data')
# Out:
# Using path './lesson2-data' for data.
# Preparing annotations export for project aGq4k6NW...
# Downloading file: mdai_public_project_aGq4k6NW_annotations_labelgroup_all_2018-09-05-183810.json
# Preparing images export for project aGq4k6NW...
# Downloading file: mdai_public_project_aGq4k6NW_images_2018-08-22-034302.zip
# 3.75MB [00:00, 150MB/s]
# Success: annotations data for project aGq4k6NW ready.
# 11.1MB [00:00, 49.0MB/s]
# Extracting archive: mdai_public_project_aGq4k6NW_images_2018-08-22-034302.zip
# Success: images data for project aGq4k6NW ready.

# %%
# download MD.ai's dilated unet implementation 
UNET_URL = 'https://s3.amazonaws.com/md.ai-ml-lessons/unet.zip'
UNET_ZIPPED = 'unet.zip'

if not os.path.exists(UNET_ZIPPED): 
    r = requests.get(UNET_URL, stream=True)
    if r.status_code == requests.codes.ok:
        with open(UNET_ZIPPED, "wb") as f:
            shutil.copyfileobj(r.raw, f)
    else:
        r.raise_for_status()

    with zipfile.ZipFile(UNET_ZIPPED) as zf:
        zf.extractall()

# %% [markdown]
# ### Set label ids
#
# Selected label ids must be explicitly set by `Project#set_label_ids` method in order to prepare datasets.

# %%
p.show_label_groups()
# Out:
# Label Group, Id: G_Vdj4o2, Name: Default group
# 	Labels:
# 	Id: L_A8Jm3d, Name: Lung

# %%
# this maps label ids to class ids as a dict obj
labels_dict = {'L_A8Jm3d':1 # Lung   
              }

print(labels_dict)
p.set_labels_dict(labels_dict)
# Out:
# {'L_A8Jm3d': 1}
# freeform

# %% [markdown]
# ### Create the *Training* and *Validation* datasets

# %%
p.show_datasets()
# Out:
# Datasets:
# Id: D_rQLwzo, Name: Dataset

# %%
dataset = p.get_dataset_by_id('D_rQLwzo')
dataset.prepare()

# %%
image_ids = dataset.get_image_ids()
len(image_ids)
# Out:
# 138

# %% [markdown]
# ### Display a few images

# %%
# visualize a few train images 
mdai.visualize.display_images(image_ids[:3], cols=2)
# Out:
# Input image pixel range exceeds 255, rescaling for visualization.
# Input image pixel range exceeds 255, rescaling for visualization.
# Input image pixel range exceeds 255, rescaling for visualization.

# %%
imgs_anns_dict = dataset.imgs_anns_dict

# %%
from unet import dataset
from unet import dilated_unet
from unet import train
# Out:
# Using TensorFlow backend.
# /content/unet

# %%
images, masks = dataset.load_images(imgs_anns_dict)

# %%
img_index = random.choice(range(len(imgs_anns_dict)))

print(img_index)
img_fps = list(imgs_anns_dict.keys())
img_fp = img_fps[img_index]
img = mdai.visualize.load_dicom_image(img_fp)
ann = imgs_anns_dict[img_fp]
img_width = img.shape[1]
img_height = img.shape[0]

mask = np.zeros((img_height, img_width), dtype=np.uint8) 
for a in ann:     
    vertices = np.array(a['data']['vertices'])
    vertices = vertices.reshape((-1,2))                     
    cv2.fillPoly(mask, np.int32([vertices]), (255,255,255))
    
plt.figure(figsize=(30, 20))
plt.subplot(2,3,1)
plt.imshow(img, cmap=plt.cm.bone)
plt.axis('off')

plt.subplot(2,3,2)
plt.imshow(mask, cmap=plt.cm.bone)
plt.axis('off')

plt.subplot(2,3,3)              
plt.imshow(cv2.bitwise_and(img, img, mask=mask.astype(np.uint8)), cmap=plt.cm.bone)
plt.axis('off')

plt.subplot(2,3,4)
plt.imshow(images[img_index,:,:,0], cmap=plt.cm.bone)
plt.axis('off')

plt.subplot(2,3,5)
plt.imshow(masks[img_index,:,:,0], cmap=plt.cm.bone)
plt.axis('off')

plt.subplot(2,3,6)
plt.imshow(cv2.bitwise_and(images[img_index,:,:,0], images[img_index,:,:,0], 
                           mask=masks[img_index,:,:,0].astype(np.uint8)), cmap=plt.cm.bone)
plt.axis('off')
# Out:
# 2
# (-0.5, 127.5, 127.5, -0.5)

# %%
import tensorflow as tf 
config = tf.ConfigProto()
config.gpu_options.allow_growth = True

# %%
CONFIG_FP = 'unet/configs/11.json'
name = os.path.basename(CONFIG_FP).split('.')[0]
print(name)
# Out:
# 11

# %%
with open(CONFIG_FP, 'r') as f:
    config = json.load(f)

# %%
# increase the number of epochs for better prediction 
history = train.train(config, name, images,masks, num_epochs=20)
# Out:
# Epoch 1/20
#  - 24s - loss: 0.5162 - acc: 0.7679 - dice: 0.0281 - iou: 0.0402 - val_loss: 0.4386 - val_acc: 0.7909 - val_dice: 3.0340e-04 - val_iou: 1.5172e-04
#
# Epoch 00001: val_loss improved from inf to 0.43864, saving model to /content/unet/trained/model_11.hdf5
# Epoch 2/20
#  - 22s - loss: 0.3818 - acc: 0.8103 - dice: 3.5888e-04 - iou: 1.7948e-04 - val_loss: 0.4204 - val_acc: 0.7909 - val_dice: 3.0340e-04 - val_iou: 1.5172e-04
#
# Epoch 00002: val_loss improved from 0.43864 to 0.42040, saving model to /content/unet/trained/model_11.hdf5
# Epoch 3/20
#  - 22s - loss: 0.3553 - acc: 0.8093 - dice: 0.0165 - iou: 0.0051 - val_loss: 0.3885 - val_acc: 0.8196 - val_dice: 0.3138 - val_iou: 0.1198
#
# Epoch 00003: val_loss improved from 0.42040 to 0.38852, saving model to /content/unet/trained/model_11.hdf5
# Epoch 4/20
#  - 23s - loss: 0.2897 - acc: 0.8831 - dice: 0.6454 - iou: 0.4427 - val_loss: 0.2619 - val_acc: 0.9093 - val_dice: 0.7761 - val_iou: 0.6294
#
# Epoch 00004: val_loss improved from 0.38852 to 0.26187, saving model to /content/unet/trained/model_11.hdf5
# Epoch 5/20
#  - 22s - loss: 0.2426 - acc: 0.9054 - dice: 0.7164 - iou: 0.5185 - val_loss: 0.2506 - val_acc: 0.9167 - val_dice: 0.8033 - val_iou: 0.7077
#
# Epoch 00005: val_loss improved from 0.26187 to 0.25060, saving model to /content/unet/trained/model_11.hdf5
# Epoch 6/20
#  - 22s - loss: 0.2551 - acc: 0.8821 - dice: 0.5903 - iou: 0.3825 - val_loss: 0.3581 - val_acc: 0.8375 - val_dice: 0.7035 - val_iou: 0.8891
#
# Epoch 00006: val_loss did not improve from 0.25060
# Epoch 7/20
#  - 22s - loss: 0.2115 - acc: 0.9160 - dice: 0.7475 - iou: 0.5571 - val_loss: 0.1833 - val_acc: 0.9287 - val_dice: 0.8288 - val_iou: 0.7347
#
# Epoch 00007: val_loss improved from 0.25060 to 0.18326, saving model to /content/unet/trained/model_11.hdf5
# Epoch 8/20
#  - 22s - loss: 0.1791 - acc: 0.9291 - dice: 0.7818 - iou: 0.6082 - val_loss: 0.2080 - val_acc: 0.9123 - val_dice: 0.8012 - val_iou: 0.7448
#
# Epoch 00008: val_loss did not improve from 0.18326
# Epoch 9/20
#  - 22s - loss: 0.1833 - acc: 0.9246 - dice: 0.7846 - iou: 0.6219 - val_loss: 0.1797 - val_acc: 0.9357 - val_dice: 0.8246 - val_iou: 0.5882
#
# Epoch 00009: val_loss improved from 0.18326 to 0.17972, saving model to /content/unet/trained/model_11.hdf5
# Epoch 10/20
#  - 22s - loss: 0.1837 - acc: 0.9250 - dice: 0.7575 - iou: 0.5467 - val_loss: 0.1715 - val_acc: 0.9312 - val_dice: 0.8296 - val_iou: 0.6941
#
# Epoch 00010: val_loss improved from 0.17972 to 0.17147, saving model to /content/unet/trained/model_11.hdf5
# Epoch 11/20
#  - 22s - loss: 0.1764 - acc: 0.9296 - dice: 0.7989 - iou: 0.6373 - val_loss: 0.1601 - val_acc: 0.9404 - val_dice: 0.8519 - val_iou: 0.7260
#
# Epoch 00011: val_loss improved from 0.17147 to 0.16005, saving model to /content/unet/trained/model_11.hdf5
# Epoch 12/20
#  - 22s - loss: 0.1656 - acc: 0.9349 - dice: 0.8110 - iou: 0.6343 - val_loss: 0.1546 - val_acc: 0.9441 - val_dice: 0.8575 - val_iou: 0.7052
#
# Epoch 00012: val_loss improved from 0.16005 to 0.15460, saving model to /content/unet/trained/model_11.hdf5
# Epoch 13/20
#  - 22s - loss: 0.1664 - acc: 0.9350 - dice: 0.8076 - iou: 0.6305 - val_loss: 0.1665 - val_acc: 0.9432 - val_dice: 0.8536 - val_iou: 0.6960
#
# Epoch 00013: val_loss did not improve from 0.15460
# Epoch 14/20
#  - 22s - loss: 0.1608 - acc: 0.9364 - dice: 0.8195 - iou: 0.6560 - val_loss: 0.1757 - val_acc: 0.9263 - val_dice: 0.8326 - val_iou: 0.8257
#
# Epoch 00014: val_loss did not improve from 0.15460
# Epoch 15/20
#  - 22s - loss: 0.1552 - acc: 0.9391 - dice: 0.8168 - iou: 0.6591 - val_loss: 0.1502 - val_acc: 0.9472 - val_dice: 0.8592 - val_iou: 0.6543
#
# Epoch 00015: val_loss improved from 0.15460 to 0.15021, saving model to /content/unet/trained/model_11.hdf5
# Epoch 16/20
#  - 22s - loss: 0.1469 - acc: 0.9428 - dice: 0.8275 - iou: 0.6719 - val_loss: 0.1459 - val_acc: 0.9430 - val_dice: 0.8643 - val_iou: 0.8158
#
# Epoch 00016: val_loss improved from 0.15021 to 0.14594, saving model to /content/unet/trained/model_11.hdf5
# Epoch 17/20
#  - 22s - loss: 0.1405 - acc: 0.9462 - dice: 0.8407 - iou: 0.6918 - val_loss: 0.1291 - val_acc: 0.9533 - val_dice: 0.8846 - val_iou: 0.7927
#
# Epoch 00017: val_loss improved from 0.14594 to 0.12915, saving model to /content/unet/trained/model_11.hdf5
# Epoch 18/20
#  - 23s - loss: 0.1492 - acc: 0.9427 - dice: 0.8345 - iou: 0.6894 - val_loss: 0.1254 - val_acc: 0.9561 - val_dice: 0.8901 - val_iou: 0.7734
#
# Epoch 00018: val_loss improved from 0.12915 to 0.12540, saving model to /content/unet/trained/model_11.hdf5
# Epoch 19/20
#  - 22s - loss: 0.1402 - acc: 0.9464 - dice: 0.8423 - iou: 0.7089 - val_loss: 0.1272 - val_acc: 0.9553 - val_dice: 0.8899 - val_iou: 0.7907
#
# Epoch 00019: val_loss did not improve from 0.12540
# Epoch 20/20
#  - 22s - loss: 0.1260 - acc: 0.9515 - dice: 0.8661 - iou: 0.7427 - val_loss: 0.1643 - val_acc: 0.9366 - val_dice: 0.8596 - val_iou: 0.9154
#
# Epoch 00020: val_loss did not improve from 0.12540

# %%
import matplotlib.pyplot as plt

print(history.history.keys())

plt.figure()
plt.plot(history.history['acc'], 'orange', label='Training accuracy')
plt.plot(history.history['val_acc'], 'blue', label='Validation accuracy')
plt.plot(history.history['loss'], 'red', label='Training loss')
plt.plot(history.history['val_loss'], 'green', label='Validation loss')
plt.legend()
plt.show()
# Out:
# dict_keys(['val_loss', 'val_acc', 'val_dice', 'val_iou', 'loss', 'acc', 'dice', 'iou'])

# %%
from keras.models import load_model
import keras.backend as K

model_name = 'unet/trained/model_'+name+'.hdf5'
print(model_name)
model = load_model(model_name, custom_objects={'dice': train.dice, 'iou': train.iou})
# Out:
# unet/trained/model_11.hdf5

# %%
images, masks = dataset.load_images(imgs_anns_dict)

plt.figure(figsize=(20, 10))

img_index = random.choice(range(len(images)))

plt.subplot(1,4,1)
random_img = images[img_index,:,:,0]
plt.imshow(random_img, cmap=plt.cm.bone)
plt.axis('off')
plt.title('Lung X-Ray')

plt.subplot(1,4,2)
random_mask = masks[img_index,:,:,0]
plt.imshow(random_mask, cmap=plt.cm.bone)
plt.axis('off')
plt.title('Mask Ground Truth')

random_img_2 = np.expand_dims(np.expand_dims(random_img, axis=0), axis=3)
mask = model.predict(random_img_2)[0][:,:,0] > 0.5
plt.subplot(1,4,3)
plt.imshow(mask, cmap=plt.cm.bone)
plt.axis('off')
plt.title('Predicted Mask')

plt.subplot(1,4,4)
plt.imshow(cv2.bitwise_and(random_img, random_img, mask=mask.astype(np.uint8)), cmap=plt.cm.bone)
plt.axis('off')
plt.title('Predicted Lung Segmentation')
# Out:
# Text(0.5,1,'Predicted Lung Segmentation')
